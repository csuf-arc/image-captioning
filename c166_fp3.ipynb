# %% [markdown]
# <a href="https://colab.research.google.com/github/csuf-arc/164-Problem-Solving-w-Search/blob/main/c166_fp3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Test 3 --- Final Test for 06.11.2025

# %%
# !pip install gymnasium[atari,accept-rom-license]
# !pip install autorom
# !pip install stable-baselines3
# Out:
# Requirement already satisfied: gymnasium[accept-rom-license,atari] in /usr/local/lib/python3.12/dist-packages (1.2.2)
# WARNING: gymnasium 1.2.2 does not provide the extra 'accept-rom-license'
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium[accept-rom-license,atari]) (2.0.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium[accept-rom-license,atari]) (3.1.2)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium[accept-rom-license,atari]) (4.15.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.12/dist-packages (from gymnasium[accept-rom-license,atari]) (0.0.4)
# Requirement already satisfied: ale_py>=0.9 in /usr/local/lib/python3.12/dist-packages (from gymnasium[accept-rom-license,atari]) (0.11.2)
# Collecting autorom
#   Downloading AutoROM-0.6.1-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: click in /usr/local/lib/python3.12/dist-packages (from autorom) (8.3.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from autorom) (2.32.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->autorom) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->autorom) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->autorom) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->autorom) (2025.11.12)
# Downloading AutoROM-0.6.1-py3-none-any.whl (9.4 kB)
# Installing collected packages: autorom
# Successfully installed autorom-0.6.1
# Collecting stable-baselines3
#   Downloading stable_baselines3-2.7.0-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: gymnasium<1.3.0,>=0.29.1 in /usr/local/lib/python3.12/dist-packages (from stable-baselines3) (1.2.2)
# Requirement already satisfied: numpy<3.0,>=1.20 in /usr/local/lib/python3.12/dist-packages (from stable-baselines3) (2.0.2)
# Requirement already satisfied: torch<3.0,>=2.3 in /usr/local/lib/python3.12/dist-packages (from stable-baselines3) (2.9.0+cu126)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.12/dist-packages (from stable-baselines3) (3.1.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from stable-baselines3) (2.2.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from stable-baselines3) (3.10.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium<1.3.0,>=0.29.1->stable-baselines3) (4.15.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.12/dist-packages (from gymnasium<1.3.0,>=0.29.1->stable-baselines3) (0.0.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (3.20.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (3.6)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (1.11.1.6)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (3.5.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->stable-baselines3) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->stable-baselines3) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->stable-baselines3) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch<3.0,>=2.3->stable-baselines3) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch<3.0,>=2.3->stable-baselines3) (3.0.3)
# Downloading stable_baselines3-2.7.0-py3-none-any.whl (187 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 187.2/187.2 kB 13.5 MB/s eta 0:00:00
# Installing collected packages: stable-baselines3
# Successfully installed stable-baselines3-2.7.0

# %%
# !AutoROM --accept-license
# Out:
# AutoROM will download the Atari 2600 ROMs.
# They will be installed to:
# 	/usr/local/lib/python3.12/dist-packages/AutoROM/roms
#
# Existing ROMs will be overwritten.
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/adventure.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/air_raid.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/alien.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/amidar.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/assault.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/asterix.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/asteroids.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/atlantis.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/atlantis2.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/backgammon.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/bank_heist.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/basic_math.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/battle_zone.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/beam_rider.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/berzerk.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/blackjack.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/bowling.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/boxing.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/breakout.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/carnival.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/casino.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/centipede.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/chopper_command.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/combat.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/crazy_climber.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/crossbow.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/darkchambers.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/defender.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/demon_attack.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/donkey_kong.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/double_dunk.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/earthworld.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/elevator_action.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/enduro.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/entombed.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/et.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/fishing_derby.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/flag_capture.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/freeway.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/frogger.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/frostbite.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/galaxian.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/gopher.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/gravitar.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/hangman.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/haunted_house.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/hero.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/human_cannonball.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/ice_hockey.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/jamesbond.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/journey_escape.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/joust.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/kaboom.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/kangaroo.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/keystone_kapers.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/king_kong.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/klax.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/koolaid.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/krull.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/kung_fu_master.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/laser_gates.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/lost_luggage.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/mario_bros.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/maze_craze.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/miniature_golf.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/montezuma_revenge.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/mr_do.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/ms_pacman.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/name_this_game.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/othello.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/pacman.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/phoenix.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/pitfall.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/pitfall2.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/pong.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/pooyan.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/private_eye.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/qbert.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/riverraid.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/road_runner.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/robotank.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/seaquest.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/sir_lancelot.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/skiing.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/solaris.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/space_invaders.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/space_war.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/star_gunner.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/superman.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/surround.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/tennis.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/tetris.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/tic_tac_toe_3d.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/time_pilot.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/trondead.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/turmoil.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/tutankham.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/up_n_down.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/venture.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/video_checkers.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/video_chess.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/video_cube.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/video_pinball.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/warlords.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/wizard_of_wor.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/word_zapper.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/yars_revenge.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/zaxxon.bin
# Done!

# %% [markdown]
# # Install the Gym

# %%
import ale_py
import gymnasium as gym

# %% [markdown]
# # Configure the model save drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
save_dir = "/content/drive/MyDrive/PUBLIC/Models"
os.makedirs(save_dir, exist_ok=True)

# %% [markdown]
# # Now Model

# %%
from dataclasses import dataclass
import argparse
import time
from datetime import datetime
import numpy as np
import collections
import typing as tt

import torch
import torch.nn as nn
import torch.optim as optim

from torch.utils.tensorboard.writer import SummaryWriter
from gymnasium.wrappers import RecordVideo
from stable_baselines3.common import atari_wrappers

# %%
#dqn_model
class DQN(nn.Module):
    def __init__(self, input_shape, n_actions):
        super(DQN, self).__init__()

        self.conv = nn.Sequential(
            nn.Conv2d(input_shape[0], 32, kernel_size=8, stride=4),
            nn.ReLU(),
            nn.Conv2d(32, 64, kernel_size=4, stride=2),
            nn.ReLU(),
            nn.Conv2d(64, 64, kernel_size=3, stride=1),
            nn.ReLU(),
            nn.Flatten(),
        )
        size = self.conv(torch.zeros(1, *input_shape)).size()[-1]
        self.fc = nn.Sequential(
            nn.Linear(size, 512),
            nn.ReLU(),
            nn.Linear(512, n_actions)
        )
    def forward(self, x: torch.ByteTensor):
        x = x.float() / 255.0
        return self.fc(self.conv(x))

# %%
#wrappers

from gymnasium import spaces
from stable_baselines3.common import atari_wrappers


class ImageToPyTorch(gym.ObservationWrapper):
    """
    ImageToPyTorch: Reorders image dimensions from (H, W, C) to (C, H, W)
    for compatibility with PyTorch convolutional layers.
    """
    def __init__(self, env):
        super(ImageToPyTorch, self).__init__(env)
        obs = self.observation_space
        assert isinstance(obs, gym.spaces.Box)
        assert len(obs.shape) == 3
        new_shape = (obs.shape[-1], obs.shape[0], obs.shape[1])
        self.observation_space = gym.spaces.Box(
            low=obs.low.min(), high=obs.high.max(),
            shape=new_shape, dtype=obs.dtype)

    def observation(self, observation):
        return np.moveaxis(observation, 2, 0)


class BufferWrapper(gym.ObservationWrapper):
    """
    BufferWrapper: Maintains a rolling window of the last `n_steps` frames
    to give the agent a sense of temporal context.
    """
    def __init__(self, env, n_steps):
        super(BufferWrapper, self).__init__(env)
        obs = env.observation_space
        assert isinstance(obs, spaces.Box)
        new_obs = gym.spaces.Box(
            obs.low.repeat(n_steps, axis=0), obs.high.repeat(n_steps, axis=0),
            dtype=obs.dtype)
        self.observation_space = new_obs
        self.buffer = collections.deque(maxlen=n_steps)

    def reset(self, *, seed: tt.Optional[int] = None, options: tt.Optional[dict[str, tt.Any]] = None):
        for _ in range(self.buffer.maxlen):
            self.buffer.append(np.zeros_like(self.env.observation_space.low))
        obs, extra = self.env.reset()
        return self.observation(obs), extra

    def observation(self, observation: np.ndarray) -> np.ndarray:
        self.buffer.append(observation)
        return np.concatenate(self.buffer)


def make_env(env_name: str, n_steps=4, render_mode=None, **kwargs):
    print(f"Creating environment {env_name}")
    env = gym.make(env_name, render_mode=render_mode, **kwargs)
    env = atari_wrappers.AtariWrapper(env, clip_reward=False, noop_max=0)
    env = ImageToPyTorch(env)
    env = BufferWrapper(env, n_steps=n_steps)
    return env
# Out:
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %%
# Base Configuration for PONG randomish
DEFAULT_ENV_NAME = "ALE/Pong-v5"
MEAN_REWARD_BOUND = 19

GAMMA = 0.99
BATCH_SIZE = 32
REPLAY_SIZE = 5000
LEARNING_RATE = 1e-4
SYNC_TARGET_FRAMES = 500
REPLAY_START_SIZE = 1000

SAVE_EPSILON = 0.5  # Only save if at least this much better
EPSILON_DECAY_LAST_FRAME = 10000
EPSILON_START = 1.0
EPSILON_FINAL = 0.01

# Tuple of tensors returned from a sampled minibatch in replay buffer
State = np.ndarray
Action = int
BatchTensors = tt.Tuple[
    torch.ByteTensor,           # current state
    torch.LongTensor,           # actions
    torch.Tensor,               # rewards
    torch.BoolTensor,           # done || trunc
    torch.ByteTensor            # next state
]

# %%
# Base Configuration for PONG improved
DEFAULT_ENV_NAME = "ALE/Pong-v5"
MEAN_REWARD_BOUND = 19

GAMMA = 0.99
BATCH_SIZE = 32
REPLAY_SIZE = 10000
LEARNING_RATE = 1e-4
SYNC_TARGET_FRAMES = 1000
REPLAY_START_SIZE = 5000

SAVE_EPSILON = 0.5  # Only save if at least this much better
EPSILON_DECAY_LAST_FRAME = 150000
EPSILON_START = 1.0
EPSILON_FINAL = 0.01

# Tuple of tensors returned from a sampled minibatch in replay buffer
State = np.ndarray
Action = int
BatchTensors = tt.Tuple[
    torch.ByteTensor,           # current state
    torch.LongTensor,           # actions
    torch.Tensor,               # rewards
    torch.BoolTensor,           # done || trunc
    torch.ByteTensor            # next state
]

# %%
# Base Configuration for space invaders early
DEFAULT_ENV_NAME = "ALE/SpaceInvaders-v5"
MEAN_REWARD_BOUND = 100

GAMMA = 0.99
BATCH_SIZE = 32
REPLAY_SIZE = 10000
LEARNING_RATE = 1e-4
SYNC_TARGET_FRAMES = 1000
REPLAY_START_SIZE = 5000

SAVE_EPSILON = 0.5  # Only save if at least this much better
EPSILON_DECAY_LAST_FRAME = 25000
EPSILON_START = 1.0
EPSILON_FINAL = 0.01

# Tuple of tensors returned from a sampled minibatch in replay buffer
State = np.ndarray
Action = int
BatchTensors = tt.Tuple[
    torch.ByteTensor,           # current state
    torch.LongTensor,           # actions
    torch.Tensor,               # rewards
    torch.BoolTensor,           # done || trunc
    torch.ByteTensor            # next state
]

# %%
# Base Configuration for space invaders learned
DEFAULT_ENV_NAME = "ALE/SpaceInvaders-v5"
MEAN_REWARD_BOUND = 600

GAMMA = 0.99
BATCH_SIZE = 32
REPLAY_SIZE = 50000
LEARNING_RATE = 1e-4
SYNC_TARGET_FRAMES = 2000
REPLAY_START_SIZE = 10000

SAVE_EPSILON = 0.5  # Only save if at least this much better
EPSILON_DECAY_LAST_FRAME = 50000
EPSILON_START = 1.0
EPSILON_FINAL = 0.01

# Tuple of tensors returned from a sampled minibatch in replay buffer
State = np.ndarray
Action = int
BatchTensors = tt.Tuple[
    torch.ByteTensor,           # current state
    torch.LongTensor,           # actions
    torch.Tensor,               # rewards
    torch.BoolTensor,           # done || trunc
    torch.ByteTensor            # next state
]

# %%
import os
from pathlib import Path

# Define directories
save_dir_drive = "/content/drive/MyDrive/PUBLIC/Models"
save_dir_local = "saved_models"

# Create both directories if they don't exist
os.makedirs(save_dir_drive, exist_ok=True)
os.makedirs(save_dir_local, exist_ok=True)

# Safe model filename
env_name = DEFAULT_ENV_NAME
safe_env_name = env_name.replace("/", "_")

# %%
@dataclass
class Experience:
    state: State
    action: Action
    reward: float
    done_trunc: bool
    new_state: State


class ExperienceBuffer:
    def __init__(self, capacity: int):
        self.buffer = collections.deque(maxlen=capacity)

    def __len__(self):
        return len(self.buffer)

    def append(self, experience: Experience):
        self.buffer.append(experience)

    def sample(self, batch_size: int) -> tt.List[Experience]:
        indices = np.random.choice(len(self), batch_size, replace=False)
        return [self.buffer[idx] for idx in indices]

# %%
class Agent:
    def __init__(self, env: gym.Env, exp_buffer: ExperienceBuffer):
        self.env = env
        self.exp_buffer = exp_buffer
        self.state: tt.Optional[np.ndarray] = None
        self._reset()

    def _reset(self):
        self.state, _ = self.env.reset()
        self.total_reward = 0.0

    @torch.no_grad()
    def play_step(self, net: DQN, device: torch.device,
                  epsilon: float = 0.0) -> tt.Optional[float]:
        done_reward = None

        if np.random.random() < epsilon:
            action = env.action_space.sample()
        else:
            state_v = torch.as_tensor(self.state).to(device)
            state_v.unsqueeze_(0)
            q_vals_v = net(state_v)
            _, act_v = torch.max(q_vals_v, dim=1)
            action = int(act_v.item())

        # do step in the environment
        new_state, reward, is_done, is_tr, _ = self.env.step(action)
        self.total_reward += reward

        exp = Experience(
            state=self.state, action=action, reward=float(reward),
            done_trunc=is_done or is_tr, new_state=new_state
        )
        self.exp_buffer.append(exp)
        self.state = new_state
        if is_done or is_tr:
            done_reward = self.total_reward
            self._reset()
        return done_reward

# %%
def batch_to_tensors(batch: tt.List[Experience], device: torch.device) -> BatchTensors:
    states, actions, rewards, dones, new_state = [], [], [], [], []
    for e in batch:
        states.append(e.state)
        actions.append(e.action)
        rewards.append(e.reward)
        dones.append(e.done_trunc)
        new_state.append(e.new_state)
    states_t = torch.as_tensor(np.asarray(states))
    actions_t = torch.LongTensor(actions)
    rewards_t = torch.FloatTensor(rewards)
    dones_t = torch.BoolTensor(dones)
    new_states_t = torch.as_tensor(np.asarray(new_state))
    return states_t.to(device), actions_t.to(device), rewards_t.to(device), \
           dones_t.to(device),  new_states_t.to(device)

# %%
def calc_loss(batch: tt.List[Experience], net: DQN, tgt_net: DQN,
              device: torch.device) -> torch.Tensor:
    states_t, actions_t, rewards_t, dones_t, new_states_t = batch_to_tensors(batch, device)

    state_action_values = net(states_t).gather(
        1, actions_t.unsqueeze(-1)
    ).squeeze(-1)
    with torch.no_grad():
        next_state_values = tgt_net(new_states_t).max(1)[0]
        next_state_values[dones_t] = 0.0
        next_state_values = next_state_values.detach()

    expected_state_action_values = next_state_values * GAMMA + rewards_t
    return nn.MSELoss()(state_action_values, expected_state_action_values)

# %%
# double DQN
def calc_loss(batch: tt.List[Experience], net: DQN, tgt_net: DQN, device: torch.device) -> torch.Tensor:
    states_t, actions_t, rewards_t, dones_t, new_states_t = batch_to_tensors(batch, device)

    q_sa = net(states_t).gather(1, actions_t.unsqueeze(-1)).squeeze(-1)

    # ✅ Double DQN target: choose with net, evaluate with tgt_net
    with torch.no_grad():
        next_actions = net(new_states_t).argmax(dim=1)
        next_q = tgt_net(new_states_t).gather(1, next_actions.unsqueeze(-1)).squeeze(-1)
        next_q[dones_t] = 0.0
        target = rewards_t + GAMMA * next_q

    return nn.MSELoss()(q_sa, target)

# %%
def record_video(env_name, model=None, epsilon=1.0, video_name="early", n_steps=4, video_folder="./videos"):
    # Pass render_mode="rgb_array" here
    env = make_env(env_name, n_steps=n_steps, render_mode="rgb_array")

    # Wrap with RecordVideo
    env = RecordVideo(env, video_folder=os.path.join(video_folder, video_name), name_prefix=video_name)

    state, _ = env.reset()
    done = False
    while not done:
        if model:
            state_v = torch.as_tensor(state).unsqueeze(0).to(device)
            q_vals = model(state_v)
            action = int(torch.argmax(q_vals, dim=1).item())
        else:
            action = env.action_space.sample()
        state, reward, done, truncated, _ = env.step(action)
    env.close()
    print(f"{video_name} video saved in {video_folder}/{video_name}")

# %%
model_comment = f"test_epsdec{EPSILON_DECAY_LAST_FRAME}_rs{REPLAY_START_SIZE}_sync{SYNC_TARGET_FRAMES}"
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

env = make_env(env_name)
net = DQN(env.observation_space.shape, env.action_space.n).to(device)
tgt_net = DQN(env.observation_space.shape, env.action_space.n).to(device)
writer = SummaryWriter(comment=f"-{env_name}-{model_comment}")
print(net)

buffer = ExperienceBuffer(REPLAY_SIZE)
agent = Agent(env, buffer)
epsilon = EPSILON_START

optimizer = optim.Adam(net.parameters(), lr=LEARNING_RATE)
total_rewards = []
frame_idx = 0
ts_frame = 0
ts = time.time()
best_m_reward = None


record_video(DEFAULT_ENV_NAME, model=None, epsilon=1.0, video_name="early")
start_time = time.time()
while True:
    frame_idx += 1
    epsilon = max(EPSILON_FINAL, EPSILON_START - frame_idx / EPSILON_DECAY_LAST_FRAME)

    reward = agent.play_step(net, device, epsilon)
    if reward is not None:
        total_rewards.append(reward)
        speed = (frame_idx - ts_frame) / (time.time() - ts)
        elapsed = time.time() - start_time  # in seconds
        ts_frame = frame_idx
        ts = time.time()
        m_reward = np.mean(total_rewards[-100:])
        #  print(f"{frame_idx}: done {len(total_rewards)} games, reward {m_reward:.3f}, "
        #      f"eps {epsilon:.2f}, speed {speed:.2f} f/s, time {elapsed/60:.1f} min")
        writer.add_scalar("epsilon", epsilon, frame_idx)
        writer.add_scalar("speed", speed, frame_idx)
        writer.add_scalar("reward_100", m_reward, frame_idx)
        writer.add_scalar("reward", reward, frame_idx)
        if best_m_reward is None or m_reward > best_m_reward + SAVE_EPSILON:
            print(f"{frame_idx}: done {len(total_rewards)} games, reward {m_reward:.3f}, "
                f"eps {epsilon:.2f}, speed {speed:.2f} f/s, time {elapsed/60:.1f} min")
            timestamp = datetime.now().strftime("%Y%m%d-%H%M")
            model_filename = f"{safe_env_name}-best_{int(m_reward)}-{timestamp}-{model_comment}.dat"

            # Save to both paths
            model_path_drive = os.path.join(save_dir_drive, model_filename)
            model_path_local = os.path.join(save_dir_local, model_filename)

            torch.save(net.state_dict(), model_path_drive)
            torch.save(net.state_dict(), model_path_local)

            print(f"💾 Model saved to:\n - Google Drive: {model_path_drive}\n - Local:        {model_path_local}")
            if best_m_reward is not None:
                print(f"Best reward updated {best_m_reward:.3f} -> {m_reward:.3f}")
            best_m_reward = m_reward
        if m_reward > MEAN_REWARD_BOUND:
            print("Solved in %d frames!" % frame_idx)
            break
    if len(buffer) < REPLAY_START_SIZE:
        continue
    if frame_idx % SYNC_TARGET_FRAMES == 0:
        tgt_net.load_state_dict(net.state_dict())

    optimizer.zero_grad()
    batch = buffer.sample(BATCH_SIZE)
    loss_t = calc_loss(batch, net, tgt_net, device)
    loss_t.backward()
    optimizer.step()
env.close()
writer.close()

record_video(DEFAULT_ENV_NAME, model=net, epsilon=0.0, video_name="learned")
# Out:
# Creating environment ALE/SpaceInvaders-v5
# DQN(
#   (conv): Sequential(
#     (0): Conv2d(4, 32, kernel_size=(8, 8), stride=(4, 4))
#     (1): ReLU()
#     (2): Conv2d(32, 64, kernel_size=(4, 4), stride=(2, 2))
#     (3): ReLU()
#     (4): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1))
#     (5): ReLU()
#     (6): Flatten(start_dim=1, end_dim=-1)
#   )
#   (fc): Sequential(
#     (0): Linear(in_features=3136, out_features=512, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=512, out_features=6, bias=True)
#   )
# )
# Creating environment ALE/SpaceInvaders-v5
# early video saved in ./videos/early
# 59: done 1 games, reward 75.000, eps 1.00, speed 53.51 f/s, time 0.0 min
# 💾 Model saved to:
#  - Google Drive: /content/drive/MyDrive/PUBLIC/Models/ALE_SpaceInvaders-v5-best_75-20251201-0704-test_epsdec50000_rs10000_sync2000.dat
#  - Local:        saved_models/ALE_SpaceInvaders-v5-best_75-20251201-0704-test_epsdec50000_rs10000_sync2000.dat
# 315: done 4 games, reward 93.750, eps 0.99, speed 243.61 f/s, time 0.0 min
# 💾 Model saved to:
#  - Google Drive: /content/drive/MyDrive/PUBLIC/Models/ALE_SpaceInvaders-v5-best_93-20251201-0704-test_epsdec50000_rs10000_sync2000.dat
#  - Local:        saved_models/ALE_SpaceInvaders-v5-best_93-20251201-0704-test_epsdec50000_rs10000_sync2000.dat
# Best reward updated 75.000 -> 93.750
# 106126: done 2239 games, reward 95.350, eps 0.01, speed 106.06 f/s, time 15.4 min
# 💾 Model saved to:
#  - Google Drive: /content/drive/MyDrive/PUBLIC/Models/ALE_SpaceInvaders-v5-best_95-20251201-0719-test_epsdec50000_rs10000_sync2000.dat
#  - Local:        saved_models/ALE_SpaceInvaders-v5-best_95-20251201-0719-test_epsdec50000_rs10000_sync2000.dat
# Best reward updated 93.750 -> 95.350
# 106249: done 2242 games, reward 96.350, eps 0.01, speed 80.40 f/s, time 15.4 min
# 💾 Model saved to:
#  - Google Drive: /content/drive/MyDrive/PUBLIC/Models/ALE_SpaceInvaders-v5-best_96-20251201-0719-test_epsdec50000_rs10000_sync2000.dat
#  - Local:        saved_models/ALE_SpaceInvaders-v5-best_96-20251201-0719-test_epsdec50000_rs10000_sync2000.dat
# Best reward updated 95.350 -> 96.350
# 106454: done 2246 games, reward 97.200, eps 0.01, speed 114.19 f/s, time 15.4 min
# 💾 Model saved to:
#  - Google Drive: /content/drive/MyDrive/PUBLIC/Models/ALE_SpaceInvaders-v5-best_97-20251201-0719-test_epsdec50000_rs10000_sync2000.dat
#  - Local:        saved_models/ALE_SpaceInvaders-v5-best_97-20251201-0719-test_epsdec50000_rs10000_sync2000.dat
# Best reward updated 96.350 -> 97.200
# 115115: done 2394 games, reward 99.650, eps 0.01, speed 116.19 f/s, time 16.8 min
# 💾 Model saved to:
#  - Google Drive: /content/drive/MyDrive/PUBLIC/Models/ALE_SpaceInvaders-v5-best_99-20251201-0721-test_epsdec50000_rs10000_sync2000.dat
#  - Local:        saved_models/ALE_SpaceInvaders-v5-best_99-20251201-0721-test_epsdec50000_rs10000_sync2000.dat
# Best reward updated 97.200 -> 99.650
# 115169: done 2395 games, reward 100.300, eps 0.01, speed 104.97 f/s, time 16.8 min
# 💾 Model saved to:
#  - Google Drive: /content/drive/MyDrive/PUBLIC/Models/ALE_SpaceInvaders-v5-best_100-20251201-0721-test_epsdec50000_rs10000_sync2000.dat
#  - Local:        saved_models/ALE_SpaceInvaders-v5-best_100-20251201-0721-test_epsdec50000_rs10000_sync2000.dat
# Best reward updated 99.650 -> 100.300
# 115263: done 2396 games, reward 101.400, eps 0.01, speed 109.17 f/s, time 16.8 min
# 💾 Model saved to:
#  - Google Drive: /content/drive/MyDrive/PUBLIC/Models/ALE_SpaceInvaders-v5-best_101-20251201-0721-test_epsdec50000_rs10000_sync2000.dat
#  - Local:        saved_models/ALE_SpaceInvaders-v5-best_101-20251201-0721-test_epsdec50000_rs10000_sync2000.dat
# Best reward updated 100.300 -> 101.400
# 115502: done 2401 games, reward 103.050, eps 0.01, speed 113.10 f/s, time 16.9 min
# 💾 Model saved to:
#  - Google Drive: /content/drive/MyDrive/PUBLIC/Models/ALE_SpaceInvaders-v5-best_103-20251201-0721-test_epsdec50000_rs10000_sync2000.dat
#  - Local:        saved_models/ALE_SpaceInvaders-v5-best_103-20251201-0721-test_epsdec50000_rs10000_sync2000.dat
# Best reward updated 101.400 -> 103.050
# 115746: done 2405 games, reward 104.000, eps 0.01, speed 115.58 f/s, time 16.9 min
# 💾 Model saved to:
#  - Google Drive: /content/drive/MyDrive/PUBLIC/Models/ALE_SpaceInvaders-v5-best_104-20251201-0721-test_epsdec50000_rs10000_sync2000.dat
#  - Local:        saved_models/ALE_SpaceInvaders-v5-best_104-20251201-0721-test_epsdec50000_rs10000_sync2000.dat
# Best reward updated 103.050 -> 104.000
# 116039: done 2411 games, reward 104.650, eps 0.01, speed 82.18 f/s, time 17.0 min
# 💾 Model saved to:
#  - Google Drive: /content/drive/MyDrive/PUBLIC/Models/ALE_SpaceInvaders-v5-best_104-20251201-0721-test_epsdec50000_rs10000_sync2000.dat
#  - Local:        saved_models/ALE_SpaceInvaders-v5-best_104-20251201-0721-test_epsdec50000_rs10000_sync2000.dat
# Best reward updated 104.000 -> 104.650
# 116095: done 2412 games, reward 105.350, eps 0.01, speed 78.16 f/s, time 17.0 min
# 💾 Model saved to:
#  - Google Drive: /content/drive/MyDrive/PUBLIC/Models/ALE_SpaceInvaders-v5-best_105-20251201-0721-test_epsdec50000_rs10000_sync2000.dat
#  - Local:        saved_models/ALE_SpaceInvaders-v5-best_105-20251201-0721-test_epsdec50000_rs10000_sync2000.dat
# Best reward updated 104.650 -> 105.350
# 116134: done 2413 games, reward 106.150, eps 0.01, speed 57.12 f/s, time 17.0 min
# 💾 Model saved to:
#  - Google Drive: /content/drive/MyDrive/PUBLIC/Models/ALE_SpaceInvaders-v5-best_106-20251201-0721-test_epsdec50000_rs10000_sync2000.dat
#  - Local:        saved_models/ALE_SpaceInvaders-v5-best_106-20251201-0721-test_epsdec50000_rs10000_sync2000.dat
# Best reward updated 105.350 -> 106.150
# 116201: done 2414 games, reward 106.800, eps 0.01, speed 80.72 f/s, time 17.0 min
# 💾 Model saved to:
#  - Google Drive: /content/drive/MyDrive/PUBLIC/Models/ALE_SpaceInvaders-v5-best_106-20251201-0721-test_epsdec50000_rs10000_sync2000.dat
#  - Local:        saved_models/ALE_SpaceInvaders-v5-best_106-20251201-0721-test_epsdec50000_rs10000_sync2000.dat
# Best reward updated 106.150 -> 106.800
# 160808: done 3371 games, reward 107.750, eps 0.01, speed 116.10 f/s, time 24.1 min
# 💾 Model saved to:
#  - Google Drive: /content/drive/MyDrive/PUBLIC/Models/ALE_SpaceInvaders-v5-best_107-20251201-0728-test_epsdec50000_rs10000_sync2000.dat
#  - Local:        saved_models/ALE_SpaceInvaders-v5-best_107-20251201-0728-test_epsdec50000_rs10000_sync2000.dat
# Best reward updated 106.800 -> 107.750
# 161005: done 3373 games, reward 109.300, eps 0.01, speed 115.62 f/s, time 24.1 min
# 💾 Model saved to:
#  - Google Drive: /content/drive/MyDrive/PUBLIC/Models/ALE_SpaceInvaders-v5-best_109-20251201-0728-test_epsdec50000_rs10000_sync2000.dat
#  - Local:        saved_models/ALE_SpaceInvaders-v5-best_109-20251201-0728-test_epsdec50000_rs10000_sync2000.dat
# Best reward updated 107.750 -> 109.300
# 161135: done 3375 games, reward 110.850, eps 0.01, speed 117.86 f/s, time 24.1 min
# 💾 Model saved to:
#  - Google Drive: /content/drive/MyDrive/PUBLIC/Models/ALE_SpaceInvaders-v5-best_110-20251201-0728-test_epsdec50000_rs10000_sync2000.dat
#  - Local:        saved_models/ALE_SpaceInvaders-v5-best_110-20251201-0728-test_epsdec50000_rs10000_sync2000.dat
# Best reward updated 109.300 -> 110.850
# 161294: done 3379 games, reward 111.900, eps 0.01, speed 112.66 f/s, time 24.2 min
# 💾 Model saved to:
#  - Google Drive: /content/drive/MyDrive/PUBLIC/Models/ALE_SpaceInvaders-v5-best_111-20251201-0728-test_epsdec50000_rs10000_sync2000.dat
#  - Local:        saved_models/ALE_SpaceInvaders-v5-best_111-20251201-0728-test_epsdec50000_rs10000_sync2000.dat
# Best reward updated 110.850 -> 111.900
# 161393: done 3380 games, reward 113.350, eps 0.01, speed 88.92 f/s, time 24.2 min
# 💾 Model saved to:
#  - Google Drive: /content/drive/MyDrive/PUBLIC/Models/ALE_SpaceInvaders-v5-best_113-20251201-0728-test_epsdec50000_rs10000_sync2000.dat
#  - Local:        saved_models/ALE_SpaceInvaders-v5-best_113-20251201-0728-test_epsdec50000_rs10000_sync2000.dat
# Best reward updated 111.900 -> 113.350
# 161586: done 3384 games, reward 114.100, eps 0.01, speed 80.76 f/s, time 24.2 min
# 💾 Model saved to:
#  - Google Drive: /content/drive/MyDrive/PUBLIC/Models/ALE_SpaceInvaders-v5-best_114-20251201-0728-test_epsdec50000_rs10000_sync2000.dat
#  - Local:        saved_models/ALE_SpaceInvaders-v5-best_114-20251201-0728-test_epsdec50000_rs10000_sync2000.dat
# Best reward updated 113.350 -> 114.100
# 161871: done 3387 games, reward 116.650, eps 0.01, speed 109.83 f/s, time 24.3 min
# 💾 Model saved to:
#  - Google Drive: /content/drive/MyDrive/PUBLIC/Models/ALE_SpaceInvaders-v5-best_116-20251201-0728-test_epsdec50000_rs10000_sync2000.dat
#  - Local:        saved_models/ALE_SpaceInvaders-v5-best_116-20251201-0728-test_epsdec50000_rs10000_sync2000.dat
# Best reward updated 114.100 -> 116.650
# 161970: done 3388 games, reward 120.000, eps 0.01, speed 109.62 f/s, time 24.3 min
# 💾 Model saved to:
#  - Google Drive: /content/drive/MyDrive/PUBLIC/Models/ALE_SpaceInvaders-v5-best_120-20251201-0728-test_epsdec50000_rs10000_sync2000.dat
#  - Local:        saved_models/ALE_SpaceInvaders-v5-best_120-20251201-0728-test_epsdec50000_rs10000_sync2000.dat
# Best reward updated 116.650 -> 120.000
# 162269: done 3392 games, reward 122.550, eps 0.01, speed 116.41 f/s, time 24.3 min
# 💾 Model saved to:
#  - Google Drive: /content/drive/MyDrive/PUBLIC/Models/ALE_SpaceInvaders-v5-best_122-20251201-0728-test_epsdec50000_rs10000_sync2000.dat
#  - Local:        saved_models/ALE_SpaceInvaders-v5-best_122-20251201-0728-test_epsdec50000_rs10000_sync2000.dat
# Best reward updated 120.000 -> 122.550
# 162711: done 3401 games, reward 125.050, eps 0.01, speed 109.00 f/s, time 24.4 min
# 💾 Model saved to:
#  - Google Drive: /content/drive/MyDrive/PUBLIC/Models/ALE_SpaceInvaders-v5-best_125-20251201-0728-test_epsdec50000_rs10000_sync2000.dat
#  - Local:        saved_models/ALE_SpaceInvaders-v5-best_125-20251201-0728-test_epsdec50000_rs10000_sync2000.dat
# Best reward updated 122.550 -> 125.050
# 182418: done 3718 games, reward 125.950, eps 0.01, speed 85.36 f/s, time 27.5 min
# 💾 Model saved to:
#  - Google Drive: /content/drive/MyDrive/PUBLIC/Models/ALE_SpaceInvaders-v5-best_125-20251201-0731-test_epsdec50000_rs10000_sync2000.dat
#  - Local:        saved_models/ALE_SpaceInvaders-v5-best_125-20251201-0731-test_epsdec50000_rs10000_sync2000.dat
# Best reward updated 125.050 -> 125.950
# 184445: done 3753 games, reward 127.200, eps 0.01, speed 111.00 f/s, time 27.8 min
# 💾 Model saved to:
#  - Google Drive: /content/drive/MyDrive/PUBLIC/Models/ALE_SpaceInvaders-v5-best_127-20251201-0732-test_epsdec50000_rs10000_sync2000.dat
#  - Local:        saved_models/ALE_SpaceInvaders-v5-best_127-20251201-0732-test_epsdec50000_rs10000_sync2000.dat
# Best reward updated 125.950 -> 127.200
# 202498: done 4053 games, reward 127.950, eps 0.01, speed 111.58 f/s, time 30.8 min
# 💾 Model saved to:
#  - Google Drive: /content/drive/MyDrive/PUBLIC/Models/ALE_SpaceInvaders-v5-best_127-20251201-0735-test_epsdec50000_rs10000_sync2000.dat
#  - Local:        saved_models/ALE_SpaceInvaders-v5-best_127-20251201-0735-test_epsdec50000_rs10000_sync2000.dat
# Best reward updated 127.200 -> 127.950
# 203080: done 4061 games, reward 128.750, eps 0.01, speed 112.35 f/s, time 30.9 min
# 💾 Model saved to:
#  - Google Drive: /content/drive/MyDrive/PUBLIC/Models/ALE_SpaceInvaders-v5-best_128-20251201-0735-test_epsdec50000_rs10000_sync2000.dat
#  - Local:        saved_models/ALE_SpaceInvaders-v5-best_128-20251201-0735-test_epsdec50000_rs10000_sync2000.dat
# Best reward updated 127.950 -> 128.750
# 203208: done 4062 games, reward 130.900, eps 0.01, speed 108.82 f/s, time 30.9 min
# 💾 Model saved to:
#  - Google Drive: /content/drive/MyDrive/PUBLIC/Models/ALE_SpaceInvaders-v5-best_130-20251201-0735-test_epsdec50000_rs10000_sync2000.dat
#  - Local:        saved_models/ALE_SpaceInvaders-v5-best_130-20251201-0735-test_epsdec50000_rs10000_sync2000.dat
# Best reward updated 128.750 -> 130.900
# 203230: done 4063 games, reward 131.550, eps 0.01, speed 97.91 f/s, time 30.9 min
# 💾 Model saved to:
#  - Google Drive: /content/drive/MyDrive/PUBLIC/Models/ALE_SpaceInvaders-v5-best_131-20251201-0735-test_epsdec50000_rs10000_sync2000.dat
#  - Local:        saved_models/ALE_SpaceInvaders-v5-best_131-20251201-0735-test_epsdec50000_rs10000_sync2000.dat
# Best reward updated 130.900 -> 131.550
# 203526: done 4066 games, reward 132.200, eps 0.01, speed 113.00 f/s, time 30.9 min
# 💾 Model saved to:
#  - Google Drive: /content/drive/MyDrive/PUBLIC/Models/ALE_SpaceInvaders-v5-best_132-20251201-0735-test_epsdec50000_rs10000_sync2000.dat
#  - Local:        saved_models/ALE_SpaceInvaders-v5-best_132-20251201-0735-test_epsdec50000_rs10000_sync2000.dat
# Best reward updated 131.550 -> 132.200
# 203695: done 4069 games, reward 133.550, eps 0.01, speed 110.23 f/s, time 31.0 min
# 💾 Model saved to:
#  - Google Drive: /content/drive/MyDrive/PUBLIC/Models/ALE_SpaceInvaders-v5-best_133-20251201-0735-test_epsdec50000_rs10000_sync2000.dat
#  - Local:        saved_models/ALE_SpaceInvaders-v5-best_133-20251201-0735-test_epsdec50000_rs10000_sync2000.dat
# Best reward updated 132.200 -> 133.550
# 203903: done 4072 games, reward 135.600, eps 0.01, speed 114.71 f/s, time 31.0 min
# 💾 Model saved to:
#  - Google Drive: /content/drive/MyDrive/PUBLIC/Models/ALE_SpaceInvaders-v5-best_135-20251201-0735-test_epsdec50000_rs10000_sync2000.dat
#  - Local:        saved_models/ALE_SpaceInvaders-v5-best_135-20251201-0735-test_epsdec50000_rs10000_sync2000.dat
# Best reward updated 133.550 -> 135.600
# 243369: done 4676 games, reward 136.650, eps 0.01, speed 120.62 f/s, time 37.2 min
# 💾 Model saved to:
#  - Google Drive: /content/drive/MyDrive/PUBLIC/Models/ALE_SpaceInvaders-v5-best_136-20251201-0741-test_epsdec50000_rs10000_sync2000.dat
#  - Local:        saved_models/ALE_SpaceInvaders-v5-best_136-20251201-0741-test_epsdec50000_rs10000_sync2000.dat
# Best reward updated 135.600 -> 136.650
# 266678: done 5037 games, reward 137.800, eps 0.01, speed 116.24 f/s, time 40.8 min
# 💾 Model saved to:
#  - Google Drive: /content/drive/MyDrive/PUBLIC/Models/ALE_SpaceInvaders-v5-best_137-20251201-0745-test_epsdec50000_rs10000_sync2000.dat
#  - Local:        saved_models/ALE_SpaceInvaders-v5-best_137-20251201-0745-test_epsdec50000_rs10000_sync2000.dat
# Best reward updated 136.650 -> 137.800
# 268754: done 5065 games, reward 139.350, eps 0.01, speed 117.16 f/s, time 41.1 min
# 💾 Model saved to:
#  - Google Drive: /content/drive/MyDrive/PUBLIC/Models/ALE_SpaceInvaders-v5-best_139-20251201-0745-test_epsdec50000_rs10000_sync2000.dat
#  - Local:        saved_models/ALE_SpaceInvaders-v5-best_139-20251201-0745-test_epsdec50000_rs10000_sync2000.dat
# Best reward updated 137.800 -> 139.350
# 269099: done 5070 games, reward 141.750, eps 0.01, speed 84.16 f/s, time 41.2 min
# 💾 Model saved to:
#  - Google Drive: /content/drive/MyDrive/PUBLIC/Models/ALE_SpaceInvaders-v5-best_141-20251201-0745-test_epsdec50000_rs10000_sync2000.dat
#  - Local:        saved_models/ALE_SpaceInvaders-v5-best_141-20251201-0745-test_epsdec50000_rs10000_sync2000.dat
# Best reward updated 139.350 -> 141.750
# 269350: done 5071 games, reward 144.050, eps 0.01, speed 114.50 f/s, time 41.2 min
# 💾 Model saved to:
#  - Google Drive: /content/drive/MyDrive/PUBLIC/Models/ALE_SpaceInvaders-v5-best_144-20251201-0745-test_epsdec50000_rs10000_sync2000.dat
#  - Local:        saved_models/ALE_SpaceInvaders-v5-best_144-20251201-0745-test_epsdec50000_rs10000_sync2000.dat
# Best reward updated 141.750 -> 144.050
# 269368: done 5072 games, reward 144.700, eps 0.01, speed 89.15 f/s, time 41.2 min
# 💾 Model saved to:
#  - Google Drive: /content/drive/MyDrive/PUBLIC/Models/ALE_SpaceInvaders-v5-best_144-20251201-0745-test_epsdec50000_rs10000_sync2000.dat
#  - Local:        saved_models/ALE_SpaceInvaders-v5-best_144-20251201-0745-test_epsdec50000_rs10000_sync2000.dat
# Best reward updated 144.050 -> 144.700
# 269445: done 5073 games, reward 146.650, eps 0.01, speed 106.29 f/s, time 41.3 min
# 💾 Model saved to:
#  - Google Drive: /content/drive/MyDrive/PUBLIC/Models/ALE_SpaceInvaders-v5-best_146-20251201-0745-test_epsdec50000_rs10000_sync2000.dat
#  - Local:        saved_models/ALE_SpaceInvaders-v5-best_146-20251201-0745-test_epsdec50000_rs10000_sync2000.dat
# Best reward updated 144.700 -> 146.650
# 269752: done 5076 games, reward 149.900, eps 0.01, speed 116.51 f/s, time 41.3 min
# 💾 Model saved to:
#  - Google Drive: /content/drive/MyDrive/PUBLIC/Models/ALE_SpaceInvaders-v5-best_149-20251201-0745-test_epsdec50000_rs10000_sync2000.dat
#  - Local:        saved_models/ALE_SpaceInvaders-v5-best_149-20251201-0745-test_epsdec50000_rs10000_sync2000.dat
# Best reward updated 146.650 -> 149.900
# 270023: done 5079 games, reward 151.900, eps 0.01, speed 116.19 f/s, time 41.3 min
# 💾 Model saved to:
#  - Google Drive: /content/drive/MyDrive/PUBLIC/Models/ALE_SpaceInvaders-v5-best_151-20251201-0745-test_epsdec50000_rs10000_sync2000.dat
#  - Local:        saved_models/ALE_SpaceInvaders-v5-best_151-20251201-0745-test_epsdec50000_rs10000_sync2000.dat
# Best reward updated 149.900 -> 151.900
# 270702: done 5090 games, reward 153.200, eps 0.01, speed 115.00 f/s, time 41.5 min
# 💾 Model saved to:
#  - Google Drive: /content/drive/MyDrive/PUBLIC/Models/ALE_SpaceInvaders-v5-best_153-20251201-0745-test_epsdec50000_rs10000_sync2000.dat
#  - Local:        saved_models/ALE_SpaceInvaders-v5-best_153-20251201-0745-test_epsdec50000_rs10000_sync2000.dat
# Best reward updated 151.900 -> 153.200
# 270882: done 5091 games, reward 157.350, eps 0.01, speed 112.40 f/s, time 41.5 min
# 💾 Model saved to:
#  - Google Drive: /content/drive/MyDrive/PUBLIC/Models/ALE_SpaceInvaders-v5-best_157-20251201-0745-test_epsdec50000_rs10000_sync2000.dat
#  - Local:        saved_models/ALE_SpaceInvaders-v5-best_157-20251201-0745-test_epsdec50000_rs10000_sync2000.dat
# Best reward updated 153.200 -> 157.350
# 273004: done 5124 games, reward 159.400, eps 0.01, speed 112.96 f/s, time 41.8 min
# 💾 Model saved to:
#  - Google Drive: /content/drive/MyDrive/PUBLIC/Models/ALE_SpaceInvaders-v5-best_159-20251201-0746-test_epsdec50000_rs10000_sync2000.dat
#  - Local:        saved_models/ALE_SpaceInvaders-v5-best_159-20251201-0746-test_epsdec50000_rs10000_sync2000.dat
# Best reward updated 157.350 -> 159.400
