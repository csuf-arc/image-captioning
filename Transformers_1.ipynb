# %% [markdown]
# <a href="https://colab.research.google.com/github/csuf-arc/image-captioning/blob/main/Transformers_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import warnings
warnings.filterwarnings(action = 'ignore')

# %%
from transformers import pipeline
from transformers.utils import logging
logging.set_verbosity(40)

# %%
from IPython.display import Image

# %%
# file 1
#https://drive.google.com/file/d/1b47sxG6Z7W8JiubMKSN38W30cbRzbTAN/view?usp=drive_link
# !gdown 1b47sxG6Z7W8JiubMKSN38W30cbRzbTAN
file_name1 = "PXL_20241130_204227352.MP~2.jpg"
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1b47sxG6Z7W8JiubMKSN38W30cbRzbTAN
# To: /content/PXL_20241130_204227352.MP~2.jpg
# 100% 1.80M/1.80M [00:00<00:00, 102MB/s]

# %%
# file 2
# https://drive.google.com/file/d/17MwA0uk4T8k9-z3fC43Qvibmxv5-EwNK/view?usp=drive_link
# !gdown 17MwA0uk4T8k9-z3fC43Qvibmxv5-EwNK
file_name2 = "PXL_20250110_190441292.jpg"
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=17MwA0uk4T8k9-z3fC43Qvibmxv5-EwNK
# To: /content/PXL_20250110_190441292.jpg
# 100% 3.74M/3.74M [00:00<00:00, 119MB/s]

# %%
# file 3
# https://drive.google.com/file/d/1K-UIDdqQE62hFYe9HQWNWaHG1K30tJ7K/view?usp=drive_link
# !gdown 1K-UIDdqQE62hFYe9HQWNWaHG1K30tJ7K
file_name3 = "PXL_20250110_184941976.jpg"
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1K-UIDdqQE62hFYe9HQWNWaHG1K30tJ7K
# To: /content/PXL_20250110_184941976.jpg
# 100% 3.94M/3.94M [00:00<00:00, 181MB/s]

# %%
### Task: Image captioning
captioner = pipeline(task="image-to-text",
                     model="nlpconnect/vit-gpt2-image-captioning")
# Out:
# config.json:   0%|          | 0.00/4.61k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/982M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/241 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/798k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/120 [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/228 [00:00<?, ?B/s]

# %%
file_name = file_name1

# %%
captioner2 = pipeline("image-to-text", model="Salesforce/blip-image-captioning-base")
# Out:
# config.json:   0%|          | 0.00/4.56k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/990M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/506 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/711k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/287 [00:00<?, ?B/s]

# %%
captioner3 = pipeline("image-to-text", model="Salesforce/blip2-opt-2.7b")
# Out:
# config.json:   0%|          | 0.00/1.03k [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/122k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/10.0G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/4.98G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/141 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/882 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/798k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/3.56M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/23.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/548 [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/432 [00:00<?, ?B/s]

# %%
captioner(file_name)
# Out:
# [{'generated_text': 'a woman holding a sign with a picture of a man on it '}]

# %%
captioner2(file_name)
# Out:
# [{'generated_text': 'a large mural of a baseball player on a building'}]

# %%
captioner3(file_name)
# Out:
# [{'generated_text': 'a mural of a baseball player on a building\n'}]

# %% [markdown]
# # Photo 1

# %%
print(captioner2(file_name1))
display(Image(filename=file_name1))
# Out:
# [{'generated_text': 'a small dog wearing a sweater in a car'}]

# %% [markdown]
# # Photo 3

# %%
display(Image(filename=file_name3))
captioner2(file_name3)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-25-cdacd29ca4c9> in <cell line: 0>()
# ----> 1 display(Image(filename=file_name3))
#       2 captioner2(file_name3)
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/display.py in __init__(self, data, url, filename, format, embed, width, height, retina, unconfined, metadata)
#    1229         self.retina = retina
#    1230         self.unconfined = unconfined
# -> 1231         super(Image, self).__init__(data=data, url=url, filename=filename,
#    1232                 metadata=metadata)
#    1233
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/display.py in __init__(self, data, url, filename, metadata)
#     635             self.metadata = {}
#     636
# --> 637         self.reload()
#     638         self._check_data()
#     639
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/display.py in reload(self)
#    1261         """Reload the raw data from file or URL."""
#    1262         if self.embed:
# -> 1263             super(Image,self).reload()
#    1264             if self.retina:
#    1265                 self._retina_shape()
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/display.py in reload(self)
#     660         """Reload the raw data from file or URL."""
#     661         if self.filename is not None:
# --> 662             with open(self.filename, self._read_flags) as f:
#     663                 self.data = f.read()
#     664         elif self.url is not None:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'IMG_7147.jpg'
